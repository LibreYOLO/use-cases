# %% [markdown]
# # Censor Faces with LibreYOLO
#
# End-to-end pipeline: download WIDERFACE, train RF-DETR Nano, evaluate, blur faces in any image.
#
# Source: https://github.com/LibreYOLO/use-cases/tree/main/censor-faces

# %% [markdown]
# ## 1. Install

# %%
# !git clone https://github.com/LibreYOLO/use-cases
# %cd use-cases/censor-faces
# !pip install -r requirements.txt

# %% [markdown]
# ## 2. Download dataset (small WIDERFACE subset)

# %%
# !python -m src.download_widerface --train-images 80 --val-images 20

# %% [markdown]
# ## 3. Train

# %%
# !python -m src.train --epochs 2 --batch 4 --imgsz 384

# %% [markdown]
# ## 4. Evaluate

# %%
# !python -m src.eval

# %% [markdown]
# ## 5. Censor a sample image
#
# Pick any image with faces, including one from the dataset itself.

# %%
import glob
samples = sorted(glob.glob('data/widerface/images/val/*.jpg'))
sample = samples[0]
print('censoring', sample)
# !python -m src.censor --image {sample} --out /tmp/censored.jpg --conf 0.25

# %%
from IPython.display import Image, display
print('before:'); display(Image(sample))
print('after:'); display(Image('/tmp/censored.jpg'))
